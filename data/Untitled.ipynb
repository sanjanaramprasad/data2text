# %%
import json

def read_rr_file(filename):
    with open(filename, 'r') as fp:
        data = json.load(fp)
    return data

# %%
rr_train = read_rr_file('/Users/sanjana/destruct/destruct/data/roboreviewer/RR-train.json')
abs_train = read_rr_file('/Users/sanjana/destruct/destruct/data/roboreviewer/abstracts-summarization-train.json')

# %%
rid = abs_train['ReviewID']['57']
rid
# Out:
# 'CD002240'

# %%
rr_train['CD002240']
# Out:
# [{'sample_size': '134',
#   'population': ['tertiary hospital in The Netherlands, 134 children aged 4 to 18 years with functional constipation',
#    'children with functional fecal incontinence associated with constipation',
#    'childhood constipation'],
#   'population_mesh': [{'mesh_term': 'Tertiary Care Centers',
#     'mesh_ui': 'D062606',
#     'cui': 'C0587437'},
#    {'mesh_term': 'Netherlands', 'mesh_ui': 'D009426', 'cui': 'C0027778'},
#    {'mesh_term': 'Child', 'mesh_ui': 'D002648', 'cui': 'C0008059'},
#    {'mesh_term': 'Aging', 'mesh_ui': 'D000375', 'cui': 'C0001811'},
#    {'mesh_term': 'Constipation', 'mesh_ui': 'D003248', 'cui': 'C0009806'},
#    {'mesh_term': 'Fecal Incontinence',
#     'mesh_ui': 'D005242',
#     'cui': 'C0015732'}],
#   'interventions': ['Behavioral therapy',
#    'laxative therapy',
#    'behavioral therapy or conventional treatment',
#    'conventional treatment',
#    'Behavioral therapy with laxatives',
#    'behavioral therapy with laxatives'],
#   'interventions_mesh': [{'mesh_term': 'Behavior Therapy',
#     'mesh_ui': 'D001521',
#     'cui': 'C0004933'},
#    {'mesh_term': 'Laxatives', 'mesh_ui': 'D054368', 'cui': 'C0282090'},
#    {'mesh_term': 'Therapeutics', 'mesh_ui': 'D013812', 'cui': 'C0087111'}],
#   'outcomes': ['defecation frequency, fecal incontinence frequency, and success rate',
#    'success rates',
#    'stool-withholding behavior and behavior problems',
#    'Defecation frequency',
#    'defecation frequency of > or = 3 times per week and fecal incontinence frequency',
#    'Fecal incontinence frequency',
#    'proportion of children with behavior problems',
#    'proportion of children withholding stools'],
#   'outcomes_mesh': [{'mesh_term': 'Defecation',
#     'mesh_ui': 'D003672',
#     'cui': 'C0011135'},
#    {'mesh_term': 'frequency', 'mesh_ui': 'Q000453', 'cui': 'C0376249'},
#    {'mesh_term': 'Fecal Incontinence',
#     'mesh_ui': 'D005242',
#     'cui': 'C0015732'},
#    {'mesh_term': 'Feces', 'mesh_ui': 'D005243', 'cui': 'C0015733'},
#    {'mesh_term': 'Behavior', 'mesh_ui': 'D001519', 'cui': 'C0004927'},
#    {'mesh_term': 'Time', 'mesh_ui': 'D013995', 'cui': 'C0040223'},
#    {'mesh_term': 'Child', 'mesh_ui': 'D002648', 'cui': 'C0008059'}],
#   'punchline_text': 'After 22 weeks, success rates did not differ between conventional treatment and behavioral therapy (respectively, 62.3% and 51.5%), nor did it differ at 6 months of follow-up (respectively, 57.3% and 42.3%).',
#   'punchline_effect': '― no diff',
#   'random_sequence_generation': {'judgement': 'low'},
#   'allocation_concealment': {'judgement': 'low'},
#   'blinding_participants_personnel': {'judgement': 'low'}},
#  {'sample_size': '87',
#   'population': ['Eighty-seven children participated in the study, 72 boys and 15 girls',
#    'childhood encopresis',
#    'Mean age at enrollment was 8.6 ',
#    'Children, 6 to 15 years of age, who experienced at least weekly fecal soiling for 6 months or longer were eligible for the study',
#    'children experiencing chronic encopresis'],
#   'population_mesh': [{'mesh_term': 'Child',
#     'mesh_ui': 'D002648',
#     'cui': 'C0008059'},
#    {'mesh_term': 'Boys', 'mesh_ui': 'D008571', 'cui': 'C0870221'},
#    {'mesh_term': 'Women', 'mesh_ui': 'D014930', 'cui': 'C0043210'},
#    {'mesh_term': 'Encopresis', 'mesh_ui': 'D004688', 'cui': 'C0014089'},
#    {'mesh_term': 'Aging', 'mesh_ui': 'D000375', 'cui': 'C0001811'},
#    {'mesh_term': 'Fecal Soiling', 'mesh_ui': 'D005242', 'cui': 'C2921133'}],
#   'interventions': ['intensive medical therapy (IMT',
#    'intensive medical therapy plus a behavior management program called enhanced toilet training (ETT), or a group that received intensive medical therapy with enhanced toilet training and external anal sphincter electromyographic biofeedback (BF',
#    'Enhanced toilet training'],
#   'interventions_mesh': [{'mesh_term': 'Therapeutics',
#     'mesh_ui': 'D013812',
#     'cui': 'C0087111'},
#    {'mesh_term': 'Behavior', 'mesh_ui': 'D001519', 'cui': 'C0004927'},
#    {'mesh_term': 'Programs', 'mesh_ui': 'D019542', 'cui': 'C0376691'},
#    {'mesh_term': 'Toilet Training', 'mesh_ui': 'D014039', 'cui': 'C0040365'},
#    {'mesh_term': 'Population Groups', 'mesh_ui': 'D044382', 'cui': 'C1257890'},
#    {'mesh_term': 'External Anal Sphincter',
#     'mesh_ui': 'D001003',
#     'cui': 'C0224395'},
#    {'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'}],
#   'outcomes': ['improvement rates',
#    'daily frequency of soiling',
#    'mean duration of symptoms',
#    'total cure rates',
#    'laxative medication',
#    'average daily soiling',
#    'cure rates',
#    'daily bowel movements'],
#   'outcomes_mesh': [{'mesh_term': 'frequency',
#     'mesh_ui': 'Q000453',
#     'cui': 'C0376249'},
#    {'mesh_term': 'Soil', 'mesh_ui': 'D012987', 'cui': 'C0037592'},
#    {'mesh_term': 'symptoms', 'mesh_ui': 'Q000175', 'cui': 'C0683368'},
#    {'mesh_term': 'Laxatives', 'mesh_ui': 'D054368', 'cui': 'C0282090'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'}],
#   'punchline_text': 'At 12 months, children were classified as significantly improved (reduction in soiling, P < 0.001) or cured (<one fecal accident in 2 weeks).\n                ',
#   'punchline_effect': '↑ sig increase',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '12',
#   'population': ['16 control children',
#    '12 patients',
#    'patients with myelomeningocele and fecal incontinence',
#    'patients with myelomeningocele'],
#   'population_mesh': [{'mesh_term': 'control',
#     'mesh_ui': 'Q000517',
#     'cui': 'C0243148'},
#    {'mesh_term': 'Child', 'mesh_ui': 'D002648', 'cui': 'C0008059'},
#    {'mesh_term': 'Patient', 'mesh_ui': 'D010361', 'cui': 'C0030705'},
#    {'mesh_term': 'Meningomyelocele', 'mesh_ui': 'D008591', 'cui': 'C0025312'},
#    {'mesh_term': 'Fecal Incontinence',
#     'mesh_ui': 'D005242',
#     'cui': 'C0015732'}],
#   'interventions': ['conventional treatment alone, or in conjunction with biofeedback',
#    'Biofeedback training',
#    'biofeedback training'],
#   'interventions_mesh': [{'mesh_term': 'Therapeutics',
#     'mesh_ui': 'D013812',
#     'cui': 'C0087111'},
#    {'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'},
#    {'mesh_term': 'training', 'mesh_ui': 'Q000193', 'cui': 'C2673163'}],
#   'outcomes': ['anal squeeze, rectal sensation or continence of rectal infused saline',
#    'frequency of soiling',
#    'Anorectal manometric functions'],
#   'outcomes_mesh': [{'mesh_term': 'Sensation',
#     'mesh_ui': 'D012677',
#     'cui': 'C0036658'},
#    {'mesh_term': 'Saline Solution',
#     'mesh_ui': 'D000077330',
#     'cui': 'C0036082'},
#    {'mesh_term': 'frequency', 'mesh_ui': 'Q000453', 'cui': 'C0376249'},
#    {'mesh_term': 'Soil', 'mesh_ui': 'D012987', 'cui': 'C0037592'},
#    {'mesh_term': 'physiology', 'mesh_ui': 'Q000502', 'cui': 'C0031843'}],
#   'punchline_text': 'Biofeedback training did not improve anal squeeze, rectal sensation or continence of rectal infused saline.',
#   'punchline_effect': '― no diff',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '21',
#   'population': ['children with encopresis',
#    '21 patients, with average ages of 10.13 and 8.54 years in each group',
#    'Children with encopresis (costiveness'],
#   'population_mesh': [{'mesh_term': 'Child',
#     'mesh_ui': 'D002648',
#     'cui': 'C0008059'},
#    {'mesh_term': 'Encopresis', 'mesh_ui': 'D004688', 'cui': 'C0014089'},
#    {'mesh_term': 'Patient', 'mesh_ui': 'D010361', 'cui': 'C0030705'},
#    {'mesh_term': 'Aging', 'mesh_ui': 'D000375', 'cui': 'C0001811'},
#    {'mesh_term': 'Population Groups', 'mesh_ui': 'D044382', 'cui': 'C1257890'},
#    {'mesh_term': 'Constipation', 'mesh_ui': 'D003248', 'cui': 'C0009806'}],
#   'interventions': ['BFB'],
#   'interventions_mesh': [],
#   'outcomes': ['percentage of internal anal sphincter (IAE) relaxation, relaxation interval of the IAE and rectal sensation threshold (RST'],
#   'outcomes_mesh': [{'mesh_term': 'Internal Anal Sphincter',
#     'mesh_ui': 'D001003',
#     'cui': 'C0224394'},
#    {'mesh_term': 'Relaxation', 'mesh_ui': 'D012063', 'cui': 'C0035028'},
#    {'mesh_term': 'Sensation', 'mesh_ui': 'D012677', 'cui': 'C0036658'}],
#   'punchline_text': 'Those treated with BFB showed clinical improvement, with manometric significant enhancement (p < 0.001) of the percentage of internal anal sphincter (IAE) relaxation, relaxation interval of the IAE and rectal sensation threshold (RST), on the other hand, patients treated by conventional therapy only improved the RST (p < 0.01).',
#   'punchline_effect': '↑ sig increase',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '48',
#   'population': ['48 children',
#    'children with functional nonretentive fecal soiling',
#    'children'],
#   'population_mesh': [{'mesh_term': 'Child',
#     'mesh_ui': 'D002648',
#     'cui': 'C0008059'},
#    {'mesh_term': 'Fecal Soiling', 'mesh_ui': 'D005242', 'cui': 'C2921133'}],
#   'interventions': ['laxatives',
#    'laxative treatment and biofeedback therapy (BF',
#    'laxative',
#    'Biofeedback was performed with perfused manometry catheters and rectal balloon distension',
#    'oral laxatives (LAX) and 5 sessions of BF (BF + LAX) or 5 sessions of BF alone (BF',
#    'BF in combination with laxatives'],
#   'interventions_mesh': [{'mesh_term': 'Laxatives',
#     'mesh_ui': 'D054368',
#     'cui': 'C0282090'},
#    {'mesh_term': 'Therapeutics', 'mesh_ui': 'D013812', 'cui': 'C0087111'},
#    {'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'},
#    {'mesh_term': 'Manometry', 'mesh_ui': 'D008365', 'cui': 'C0024751'},
#    {'mesh_term': 'Catheters', 'mesh_ui': 'D057785', 'cui': 'C0085590'},
#    {'mesh_term': 'Dilatation, Pathologic',
#     'mesh_ui': 'D004108',
#     'cui': 'C0012359'}],
#   'outcomes': ['success rates', 'number of encopresis episodes'],
#   'outcomes_mesh': [{'mesh_term': 'Encopresis',
#     'mesh_ui': 'D004688',
#     'cui': 'C0014089'}],
#   'punchline_text': 'At the end of the intervention period, the number of encopresis episodes was significantly decreased in both groups: from 7 (2 to 24) to 2 (0 to 17) in the BF group and from 7 (3 to 25) to 2 (0 to 14) in the BF + LAX group.',
#   'punchline_effect': '↓ sig decrease',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '212',
#   'population': ['212 constipated children (143 boys) who were visiting a referral pediatric gastroenterologic practice',
#    'Patients were included in the study when they fulfilled at least 2 of the 4 following criteria: stool frequency fewer than 3 per week, 2 or more soiling and/or encopresis episodes per week, periodic passage of very large amounts of stool every 7 to 30 days, or a palpable rectal or abdominal fecal mass',
#    'chronically constipated children',
#    'severe childhood constipation',
#    'severely constipated children who are referred to a tertiary hospital, underscoring the importance of long-lasting and adequate laxative treatment'],
#   'population_mesh': [{'mesh_term': 'Constipation',
#     'mesh_ui': 'D003248',
#     'cui': 'C0009806'},
#    {'mesh_term': 'Child', 'mesh_ui': 'D002648', 'cui': 'C0008059'},
#    {'mesh_term': 'Boys', 'mesh_ui': 'D008571', 'cui': 'C0870221'},
#    {'mesh_term': 'Referral', 'mesh_ui': 'D012017', 'cui': 'C0034927'},
#    {'mesh_term': 'Pediatrics', 'mesh_ui': 'D010372', 'cui': 'C0030755'},
#    {'mesh_term': 'Patient', 'mesh_ui': 'D010361', 'cui': 'C0030705'},
#    {'mesh_term': 'criteria', 'mesh_ui': 'Q000592', 'cui': 'C0243161'},
#    {'mesh_term': 'Feces', 'mesh_ui': 'D005243', 'cui': 'C0015733'},
#    {'mesh_term': 'frequency', 'mesh_ui': 'Q000453', 'cui': 'C0376249'},
#    {'mesh_term': 'Encopresis', 'mesh_ui': 'D004688', 'cui': 'C0014089'},
#    {'mesh_term': 'Tertiary Care Centers',
#     'mesh_ui': 'D062606',
#     'cui': 'C0587437'},
#    {'mesh_term': 'Laxatives', 'mesh_ui': 'D054368', 'cui': 'C0282090'},
#    {'mesh_term': 'Therapeutics', 'mesh_ui': 'D013812', 'cui': 'C0087111'}],
#   'interventions': ['CT',
#    'biofeedback training (BF',
#    'CT alone (dietary advice, diary, toilet training, oral laxatives, and enemas',
#    'Anorectal manometry combined with CT',
#    'CT alone',
#    'CTM',
#    'anorectal manometry',
#    'CT and CTM',
#    'CT combined with 2 manometry sessions'],
#   'interventions_mesh': [{'mesh_term': 'Therapeutics',
#     'mesh_ui': 'D013812',
#     'cui': 'C0087111'},
#    {'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'},
#    {'mesh_term': 'training', 'mesh_ui': 'Q000193', 'cui': 'C2673163'},
#    {'mesh_term': 'Diary', 'mesh_ui': 'D019497', 'cui': 'C0376660'},
#    {'mesh_term': 'Toilet Training', 'mesh_ui': 'D014039', 'cui': 'C0040365'},
#    {'mesh_term': 'Laxatives', 'mesh_ui': 'D054368', 'cui': 'C0282090'},
#    {'mesh_term': 'Enema', 'mesh_ui': 'D004733', 'cui': 'C0014268'},
#    {'mesh_term': 'Manometry', 'mesh_ui': 'D008365', 'cui': 'C0024751'}],
#   'outcomes': ['success rates',
#    'periodic passage of large stools',
#    'encopresis episodes',
#    'defecation frequency',
#    'success percentage',
#    'soiling and/or encopresis'],
#   'outcomes_mesh': [{'mesh_term': 'Feces',
#     'mesh_ui': 'D005243',
#     'cui': 'C0015733'},
#    {'mesh_term': 'Encopresis', 'mesh_ui': 'D004688', 'cui': 'C0014089'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'},
#    {'mesh_term': 'frequency', 'mesh_ui': 'Q000453', 'cui': 'C0376249'},
#    {'mesh_term': 'Soil', 'mesh_ui': 'D012987', 'cui': 'C0037592'}],
#   'punchline_text': 'Anorectal manometry combined with CT compared with CT alone did not result in higher success rates in chronically constipated children.',
#   'punchline_effect': '― no diff',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '8',
#   'population': ['fecal incontinence'],
#   'population_mesh': [{'mesh_term': 'Fecal Incontinence',
#     'mesh_ui': 'D005242',
#     'cui': 'C0015732'}],
#   'interventions': ['sensory discrimination training, one to exercise training'],
#   'interventions_mesh': [{'mesh_term': 'Discrimination (Psychology)',
#     'mesh_ui': 'D004192',
#     'cui': 'C0012632'},
#    {'mesh_term': 'training', 'mesh_ui': 'Q000193', 'cui': 'C2673163'},
#    {'mesh_term': 'Exercise Training',
#     'mesh_ui': 'D015444',
#     'cui': 'C4279936'}],
#   'outcomes': ['rectosphincteric reflexes'],
#   'outcomes_mesh': [{'mesh_term': 'Reflex',
#     'mesh_ui': 'D012018',
#     'cui': 'C0034929'}],
#   'punchline_text': 'Despite the achievement of continence, the rectosphincteric reflexes following treatment continued to be abnormal in every case.',
#   'punchline_effect': '― no diff',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '30',
#   'population': ['children with dyssynergic defecation and constipation/encopresis',
#    'children with dyssynergic defecation and recalcitrant constipation/encopresis',
#    'Thirty patients were available for long-term follow-up',
#    'children with chronic constipation and dyssynergic defecation',
#    'Thirty-six patients with chronic constipation who had failed at least 6 months of conventional treatment and demonstrated dyssynergic defecation at anorectal manometry'],
#   'population_mesh': [{'mesh_term': 'Child',
#     'mesh_ui': 'D002648',
#     'cui': 'C0008059'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'},
#    {'mesh_term': 'Constipation', 'mesh_ui': 'D003248', 'cui': 'C0009806'},
#    {'mesh_term': 'Encopresis', 'mesh_ui': 'D004688', 'cui': 'C0014089'},
#    {'mesh_term': 'Patient', 'mesh_ui': 'D010361', 'cui': 'C0030705'},
#    {'mesh_term': 'Therapeutics', 'mesh_ui': 'D013812', 'cui': 'C0087111'},
#    {'mesh_term': 'Manometry', 'mesh_ui': 'D008365', 'cui': 'C0024751'}],
#   'interventions': ['Biofeedback'],
#   'interventions_mesh': [{'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'}],
#   'outcomes': ['Soiling', 'Laxative use', 'Bowel movements'],
#   'outcomes_mesh': [{'mesh_term': 'Soil',
#     'mesh_ui': 'D012987',
#     'cui': 'C0037592'},
#    {'mesh_term': 'Laxatives', 'mesh_ui': 'D054368', 'cui': 'C0282090'},
#    {'mesh_term': 'utilization', 'mesh_ui': 'Q000706', 'cui': 'C0042153'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'}],
#   'punchline_text': 'Laxative use decreased from a mean of 4.1 days/week to 0.6, 0.3, and 0.7 per week at 2 months, 4 months, and long-term, respectively (p < or = 0.001).',
#   'punchline_effect': '― no diff',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': 'not found',
#   'population': ['children with lower bowel function disorders'],
#   'population_mesh': [{'mesh_term': 'Child',
#     'mesh_ui': 'D002648',
#     'cui': 'C0008059'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'},
#    {'mesh_term': 'Diseases', 'mesh_ui': 'D004194', 'cui': 'C0012634'}],
#   'interventions': [],
#   'interventions_mesh': [],
#   'outcomes': [],
#   'outcomes_mesh': [],
#   'punchline_text': 'Simple, incentive based behaviour modification, with or without a modest programme of psychotherapy involving outpatient visits every four to six weeks, seems to be associated with a useful cure rate in children with lower bowel function disorders.',
#   'punchline_effect': '↓ sig decrease',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '68',
#   'population': ['children with anismus using',
#    'Sixty eight children underwent',
#    '29 had anismus (ages 4-14 years',
#    'children with encopresis',
#    'persistent encopresis with anismus'],
#   'population_mesh': [{'mesh_term': 'Child',
#     'mesh_ui': 'D002648',
#     'cui': 'C0008059'},
#    {'mesh_term': 'Aging', 'mesh_ui': 'D000375', 'cui': 'C0001811'},
#    {'mesh_term': 'Encopresis', 'mesh_ui': 'D004688', 'cui': 'C0014089'}],
#   'interventions': ['EMG biofeedback training and conventional medical treatment (BFT',
#    'surface electromyographic (EMG) biofeedback training',
#    'Biofeedback training',
#    'anorectal manometry and EMG',
#    'biofeedback training',
#    'conventional medical treatment alone',
#    'BFT',
#    'Paradoxical external anal sphincter contraction'],
#   'interventions_mesh': [{'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'},
#    {'mesh_term': 'training', 'mesh_ui': 'Q000193', 'cui': 'C2673163'},
#    {'mesh_term': 'Therapeutics', 'mesh_ui': 'D013812', 'cui': 'C0087111'},
#    {'mesh_term': 'Manometry', 'mesh_ui': 'D008365', 'cui': 'C0024751'},
#    {'mesh_term': 'External Anal Sphincter',
#     'mesh_ui': 'D001003',
#     'cui': 'C0224395'}],
#   'outcomes': ['CBCL school scale scores',
#    'Mean CBCL total behaviour problem scores',
#    'Rectal hyposensitivity',
#    'laxative free remission',
#    'Anorectal manometry',
#    'Remission or improvement',
#    'child behaviour checklist" (CBCL'],
#   'outcomes_mesh': [{'mesh_term': 'Child',
#     'mesh_ui': 'D002648',
#     'cui': 'C0008059'},
#    {'mesh_term': 'Checklist', 'mesh_ui': 'D057189', 'cui': 'C1707357'},
#    {'mesh_term': 'School', 'mesh_ui': 'D012574', 'cui': 'C0036375'},
#    {'mesh_term': 'Scales', 'mesh_ui': 'D014894', 'cui': 'C0175659'},
#    {'mesh_term': 'Laxatives', 'mesh_ui': 'D054368', 'cui': 'C0282090'},
#    {'mesh_term': 'Manometry', 'mesh_ui': 'D008365', 'cui': 'C0024751'}],
#   'punchline_text': "At six months' follow up, laxative free remission had been sustained in two of 14 patients in the BFT group and in two of 15 controls (95% confidence interval (CI) on difference, -24% to 26%).",
#   'punchline_effect': '↑ sig increase',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '50',
#   'population': ['childhood encopresis',
#    'children with normal (n = 32) and abnormal (n = 18) defecation patterns',
#    'children with encopresis and abnormal defecation patterns',
#    '50 children with encopresis',
#    '24 children receiving B and the 26 children receiving M at 3, 6, and 12 months'],
#   'population_mesh': [{'mesh_term': 'Encopresis',
#     'mesh_ui': 'D004688',
#     'cui': 'C0014089'},
#    {'mesh_term': 'Child', 'mesh_ui': 'D002648', 'cui': 'C0008059'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'}],
#   'interventions': ['biofeedback (B) or mineral oil therapy (M'],
#   'interventions_mesh': [{'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'},
#    {'mesh_term': 'Mineral Oil', 'mesh_ui': 'D008899', 'cui': 'C0026156'},
#    {'mesh_term': 'Therapeutics', 'mesh_ui': 'D013812', 'cui': 'C0087111'}],
#   'outcomes': ['Specificity of biofeedback', 'abnormal defecation patterns'],
#   'outcomes_mesh': [{'mesh_term': 'Specificity',
#     'mesh_ui': 'D012680',
#     'cui': 'C0037791'},
#    {'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'}],
#   'punchline_text': 'Using a single blinded design, there were no significant differences in clinical outcomes between the 24 children receiving B and the 26 children receiving M at 3, 6, and 12 months.',
#   'punchline_effect': '― no diff',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '49',
#   'population': ['Forty-nine children with chronic idiopathic constipation, 24 allocated to conventional and 25 to biofeedback therapy were included in the study',
#    'chronic constipation in children'],
#   'population_mesh': [{'mesh_term': 'Child',
#     'mesh_ui': 'D002648',
#     'cui': 'C0008059'},
#    {'mesh_term': 'Constipation', 'mesh_ui': 'D003248', 'cui': 'C0009806'},
#    {'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'}],
#   'interventions': ['biofeedback versus conventional therapeutic protocol',
#    'biofeedback therapy'],
#   'interventions_mesh': [{'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'},
#    {'mesh_term': 'Therapeutics', 'mesh_ui': 'D013812', 'cui': 'C0087111'}],
#   'outcomes': ['chronic constipation',
#    'prevalence of abnormal defecation dynamics',
#    'Chronic constipation',
#    'bowel function and symptoms, anorectal status and manometric testing',
#    'abnormal defecation dynamics',
#    'values of rectal sensation threshold, critical volume, and recto-anal inhibitory reflex volume'],
#   'outcomes_mesh': [{'mesh_term': 'Constipation',
#     'mesh_ui': 'D003248',
#     'cui': 'C0009806'},
#    {'mesh_term': 'Prevalence', 'mesh_ui': 'D015995', 'cui': 'C0033105'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'},
#    {'mesh_term': 'symptoms', 'mesh_ui': 'Q000175', 'cui': 'C0683368'},
#    {'mesh_term': 'Sensation', 'mesh_ui': 'D012677', 'cui': 'C0036658'},
#    {'mesh_term': 'Reflex', 'mesh_ui': 'D012018', 'cui': 'C0034929'}],
#   'punchline_text': 'The initial prevalence of abnormal defecation dynamics was 58% and 56% in the group children allocated to conventional and biofeedback therapy, respectively.',
#   'punchline_effect': '↑ sig increase',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '94',
#   'population': ['Patients had a medical history, abdominal and rectal examination, and anorectal manometry at the start and end of the 6-week intervention period',
#    'chronically constipated children',
#    'Patients, 5 to 16 years old, were referred to the Academic Medical Center in Amsterdam by general practitioners, school doctors, paediatricians, and psychiatrists',
#    'They had to fulfil at least two of four criteria for paediatric constipation and were included if they had been treated medically for at least one month before randomisation',
#    '94 patients',
#    'childhood constipation'],
#   'population_mesh': [{'mesh_term': 'Patient',
#     'mesh_ui': 'D010361',
#     'cui': 'C0030705'},
#    {'mesh_term': 'History', 'mesh_ui': 'D006664', 'cui': 'C0019664'},
#    {'mesh_term': 'Abdomen', 'mesh_ui': 'D000005', 'cui': 'C0000726'},
#    {'mesh_term': 'Physical Examination',
#     'mesh_ui': 'D010808',
#     'cui': 'C0031809'},
#    {'mesh_term': 'Manometry', 'mesh_ui': 'D008365', 'cui': 'C0024751'},
#    {'mesh_term': 'Constipation', 'mesh_ui': 'D003248', 'cui': 'C0009806'},
#    {'mesh_term': 'Child', 'mesh_ui': 'D002648', 'cui': 'C0008059'},
#    {'mesh_term': 'Academic Medical Centers',
#     'mesh_ui': 'D000046',
#     'cui': 'C0000872'},
#    {'mesh_term': 'General Practitioners',
#     'mesh_ui': 'D058005',
#     'cui': 'C0017319'},
#    {'mesh_term': 'School', 'mesh_ui': 'D012574', 'cui': 'C0036375'},
#    {'mesh_term': 'Physician', 'mesh_ui': 'D010820', 'cui': 'C0031831'},
#    {'mesh_term': 'Pediatrician', 'mesh_ui': 'D000072143', 'cui': 'C0237433'},
#    {'mesh_term': 'Psychiatrist', 'mesh_ui': 'D011570', 'cui': 'C0033872'},
#    {'mesh_term': 'ANDS', 'mesh_ui': 'C019152', 'cui': 'C0047247'}],
#   'interventions': ['CT+BF',
#    'conventional treatment and conventional treatment with biofeedback training',
#    'Biofeedback training',
#    'conventional treatment (CT) and 98 to conventional treatment with additional biofeedback training (CT+BF',
#    'same conventional treatment and additionally five biofeedback training sessions',
#    'Intensive conventional laxative treatment',
#    'laxative treatment with additional dietary advice, toilet training, and maintenance of a diary of bowel habits',
#    'Additional biofeedback training'],
#   'interventions_mesh': [{'mesh_term': 'Therapeutics',
#     'mesh_ui': 'D013812',
#     'cui': 'C0087111'},
#    {'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'},
#    {'mesh_term': 'training', 'mesh_ui': 'Q000193', 'cui': 'C2673163'},
#    {'mesh_term': 'Laxatives', 'mesh_ui': 'D054368', 'cui': 'C0282090'},
#    {'mesh_term': 'Toilet Training', 'mesh_ui': 'D014039', 'cui': 'C0040365'},
#    {'mesh_term': 'Maintenance', 'mesh_ui': 'D008283', 'cui': 'C0024501'},
#    {'mesh_term': 'Diary', 'mesh_ui': 'D019497', 'cui': 'C0376660'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'}],
#   'outcomes': ['successful treatment (defaecation frequency > or = 3/week, soiling and/or encopresis < 2/month, and no laxatives',
#    'normal defaecation dynamics',
#    'Normal defaecation dynamics',
#    'success rates'],
#   'outcomes_mesh': [{'mesh_term': 'Therapeutics',
#     'mesh_ui': 'D013812',
#     'cui': 'C0087111'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'},
#    {'mesh_term': 'frequency', 'mesh_ui': 'Q000453', 'cui': 'C0376249'},
#    {'mesh_term': 'Soil', 'mesh_ui': 'D012987', 'cui': 'C0037592'},
#    {'mesh_term': 'Encopresis', 'mesh_ui': 'D004688', 'cui': 'C0014089'},
#    {'mesh_term': 'Laxatives', 'mesh_ui': 'D054368', 'cui': 'C0282090'}],
#   'punchline_text': 'At 6 weeks, more patients in the CT+BF group showed normal defaecation dynamics, compared to the CT group (p < 0.001).',
#   'punchline_effect': '↑ sig increase',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': 'not found',
#   'population': ['children with encopresis'],
#   'population_mesh': [{'mesh_term': 'Child',
#     'mesh_ui': 'D002648',
#     'cui': 'C0008059'},
#    {'mesh_term': 'Encopresis', 'mesh_ui': 'D004688', 'cui': 'C0014089'}],
#   'interventions': ['five biofeedback training sessions',
#    'laxatives and biofeedback training',
#    'Biofeedback training',
#    'biofeedback training',
#    'dietary and toilet advice, enemas, oral laxatives, and anorectal manometry'],
#   'interventions_mesh': [{'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'},
#    {'mesh_term': 'training', 'mesh_ui': 'Q000193', 'cui': 'C2673163'},
#    {'mesh_term': 'Laxatives', 'mesh_ui': 'D054368', 'cui': 'C0282090'},
#    {'mesh_term': 'Commode', 'mesh_ui': 'D000072296', 'cui': 'C1140607'},
#    {'mesh_term': 'Enema', 'mesh_ui': 'D004733', 'cui': 'C0014268'},
#    {'mesh_term': 'Manometry', 'mesh_ui': 'D008365', 'cui': 'C0024751'}],
#   'outcomes': ['success rates',
#    'behavioural profiles',
#    'behaviour scores',
#    'Abnormal behaviour scores',
#    'success rate or behaviour scores',
#    'encopresis, regular bowel movements, and no laxatives',
#    'Psychosocial function'],
#   'outcomes_mesh': [{'mesh_term': 'Problem Behavior',
#     'mesh_ui': 'D000066553',
#     'cui': 'C0233514'},
#    {'mesh_term': 'Encopresis', 'mesh_ui': 'D004688', 'cui': 'C0014089'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'},
#    {'mesh_term': 'Laxatives', 'mesh_ui': 'D054368', 'cui': 'C0282090'},
#    {'mesh_term': 'physiology', 'mesh_ui': 'Q000502', 'cui': 'C0031843'}],
#   'punchline_text': 'Children given laxatives and biofeedback training had higher success rates than those who received laxatives alone (39% v 19%) at the end of the intervention period.',
#   'punchline_effect': '↑ sig increase',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '22',
#   'population': ["chronically constipated children who fulfilled the criteria of ARD: recto-sigmoid transit time in Hinton's test with radio-paque markers at least 28.8 h, paradoxical EAS contraction during defecation trials (anorectal manometry",
#    'children with chronic functional constipation',
#    '22 constipated children (16 boys and 6 girls), aged 5 to 14 years (mean 8.1 '],
#   'population_mesh': [{'mesh_term': 'Constipation',
#     'mesh_ui': 'D003248',
#     'cui': 'C0009806'},
#    {'mesh_term': 'Child', 'mesh_ui': 'D002648', 'cui': 'C0008059'},
#    {'mesh_term': 'criteria', 'mesh_ui': 'Q000592', 'cui': 'C0243161'},
#    {'mesh_term': 'Colon, Sigmoid', 'mesh_ui': 'D012809', 'cui': 'C0227391'},
#    {'mesh_term': 'Time', 'mesh_ui': 'D013995', 'cui': 'C0040223'},
#    {'mesh_term': 'Radio', 'mesh_ui': 'D011845', 'cui': 'C0034546'},
#    {'mesh_term': 'External Anal Sphincter',
#     'mesh_ui': 'D001003',
#     'cui': 'C0224395'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'},
#    {'mesh_term': 'Manometry', 'mesh_ui': 'D008365', 'cui': 'C0024751'},
#    {'mesh_term': 'Boys', 'mesh_ui': 'D008571', 'cui': 'C0870221'},
#    {'mesh_term': 'Women', 'mesh_ui': 'D014930', 'cui': 'C0043210'},
#    {'mesh_term': 'Aging', 'mesh_ui': 'D000375', 'cui': 'C0001811'}],
#   'interventions': ['BF training',
#    'biofeedback training (BF',
#    'paradoxical contraction of the external anal sphincter (EAS',
#    'BF',
#    'biofeedback treatment'],
#   'interventions_mesh': [{'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'},
#    {'mesh_term': 'training', 'mesh_ui': 'Q000193', 'cui': 'C2673163'},
#    {'mesh_term': 'External Anal Sphincter',
#     'mesh_ui': 'D001003',
#     'cui': 'C0224395'},
#    {'mesh_term': 'Therapeutics', 'mesh_ui': 'D013812', 'cui': 'C0087111'}],
#   'outcomes': ['manometric parameters',
#    'anal-rectal dyssynergy (ARD',
#    'rectal sensation and particularly defecation dynamics',
#    'number of stools increased and their quality',
#    'manometric data, number and quality of stools'],
#   'outcomes_mesh': [{'mesh_term': 'Sensation',
#     'mesh_ui': 'D012677',
#     'cui': 'C0036658'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'},
#    {'mesh_term': 'Feces', 'mesh_ui': 'D005243', 'cui': 'C0015733'}],
#   'punchline_text': 'In the group I after one month, more manometric parameters, significantly improved as compared to the II group.',
#   'punchline_effect': '↑ sig increase',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '169',
#   'population': ['childhood encopresis',
#    '169 children with encopresis and evidence of stool on plain abdominal radiograph',
#    'children who are able to maintain regular toileting'],
#   'population_mesh': [{'mesh_term': 'Encopresis',
#     'mesh_ui': 'D004688',
#     'cui': 'C0014089'},
#    {'mesh_term': 'Child', 'mesh_ui': 'D002648', 'cui': 'C0008059'},
#    {'mesh_term': 'Feces', 'mesh_ui': 'D005243', 'cui': 'C0015733'},
#    {'mesh_term': 'Abdomen', 'mesh_ui': 'D000005', 'cui': 'C0000726'}],
#   'interventions': ['multimodal (MM) therapy (laxatives plus behaviour modification; n = 83) or behaviour modification alone',
#    'laxatives'],
#   'interventions_mesh': [{'mesh_term': 'Therapeutics',
#     'mesh_ui': 'D013812',
#     'cui': 'C0087111'},
#    {'mesh_term': 'Laxatives', 'mesh_ui': 'D054368', 'cui': 'C0282090'},
#    {'mesh_term': 'Behavior Therapy', 'mesh_ui': 'D001521', 'cui': 'C0004933'}],
#   'outcomes': ['achieved remission', 'Kaplan-Meier remission curves'],
#   'outcomes_mesh': [],
#   'punchline_text': 'The patterns of compliance with toileting in the treatment groups were almost identical, although about 1 in 8 children overall did not comply with the sitting programme.',
#   'punchline_effect': '― no diff',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '24',
#   'population': ['children with encopresis',
#    'pediatric encopresis',
#    'Twenty-four children with encopresis'],
#   'population_mesh': [{'mesh_term': 'Child',
#     'mesh_ui': 'D002648',
#     'cui': 'C0008059'},
#    {'mesh_term': 'Encopresis', 'mesh_ui': 'D004688', 'cui': 'C0014089'},
#    {'mesh_term': 'Pediatrics', 'mesh_ui': 'D010372', 'cui': 'C0030755'}],
#   'interventions': ['Internet intervention group (Web) or no Internet intervention group (No-Web',
#    'enhanced toilet training'],
#   'interventions_mesh': [{'mesh_term': 'Internet',
#     'mesh_ui': 'D020407',
#     'cui': 'C0282111'},
#    {'mesh_term': 'Population Groups', 'mesh_ui': 'D044382', 'cui': 'C1257890'},
#    {'mesh_term': 'Toilet Training', 'mesh_ui': 'D014039', 'cui': 'C0040365'}],
#   'outcomes': ['reduced fecal soiling, increased defecation',
#    'knowledge and toileting behaviors'],
#   'outcomes_mesh': [{'mesh_term': 'Fecal Soiling',
#     'mesh_ui': 'D005242',
#     'cui': 'C2921133'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'},
#    {'mesh_term': 'Knowledge', 'mesh_ui': 'D019359', 'cui': 'C0376554'},
#    {'mesh_term': 'Commode', 'mesh_ui': 'D000072296', 'cui': 'C1140607'},
#    {'mesh_term': 'Behavior', 'mesh_ui': 'D001519', 'cui': 'C0004927'}],
#   'punchline_text': 'Twenty-four children with encopresis were randomly assigned to the Internet intervention group (Web) or no Internet intervention group (No-Web).',
#   'punchline_effect': '― no diff',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': 'not found',
#   'population': ['chronically constipated children with encopresis',
#    'patients with abnormal defecation dynamics',
#    'chronically constipated and encopretic children with abnormal defecation dynamics'],
#   'population_mesh': [{'mesh_term': 'Constipation',
#     'mesh_ui': 'D003248',
#     'cui': 'C0009806'},
#    {'mesh_term': 'Child', 'mesh_ui': 'D002648', 'cui': 'C0008059'},
#    {'mesh_term': 'Encopresis', 'mesh_ui': 'D004688', 'cui': 'C0014089'},
#    {'mesh_term': 'Patient', 'mesh_ui': 'D010361', 'cui': 'C0030705'},
#    {'mesh_term': 'Defecation', 'mesh_ui': 'D003672', 'cui': 'C0011135'}],
#   'interventions': ['conventional treatment alone (n = 19) or conventional plus biofeedback treatment',
#    'biofeedback training'],
#   'interventions_mesh': [{'mesh_term': 'Therapeutics',
#     'mesh_ui': 'D013812',
#     'cui': 'C0087111'},
#    {'mesh_term': 'Biofeedback, Psychology',
#     'mesh_ui': 'D001676',
#     'cui': 'C0005491'},
#    {'mesh_term': 'training', 'mesh_ui': 'Q000193', 'cui': 'C2673163'}],
#   'outcomes': ['Balloon defecation',
#    'abnormal defecation dynamics',
#    'Learning normal defecation dynamics',
#    'normal defecation dynamics'],
#   'outcomes_mesh': [{'mesh_term': 'Defecation',
#     'mesh_ui': 'D003672',
#     'cui': 'C0011135'},
#    {'mesh_term': 'Learning', 'mesh_ui': 'D007858', 'cui': 'C0023185'}],
#   'punchline_text': 'At 7 months, 13% of conventionally treated and 77% of biofeedback-treated patients had normal defecation dynamics (p less than 0.01); one conventionally treated (5%) and 12 biofeedback-treated patients (55%) had recovered (p less than 0.01).',
#   'punchline_effect': '― no diff',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}},
#  {'sample_size': '40',
#   'population': ['40 children with severe and persistent soiling and often with a history of faecal retention'],
#   'population_mesh': [{'mesh_term': 'Child',
#     'mesh_ui': 'D002648',
#     'cui': 'C0008059'},
#    {'mesh_term': 'History', 'mesh_ui': 'D006664', 'cui': 'C0019664'},
#    {'mesh_term': 'Retention (Psychology)',
#     'mesh_ui': 'D012153',
#     'cui': 'C0035280'}],
#   'interventions': ['Senokot, placebo'],
#   'interventions_mesh': [{'mesh_term': 'Senokot',
#     'mesh_ui': 'C002839',
#     'cui': 'C0699932'},
#    {'mesh_term': 'Placebos', 'mesh_ui': 'D010919', 'cui': 'C0032042'}],
#   'outcomes': [],
#   'outcomes_mesh': [],
#   'punchline_text': 'Significant improvement occurred following three months of outpatient treatment using a behavioural approach and either Senokot, placebo or no medication.',
#   'punchline_effect': '↓ sig decrease',
#   'random_sequence_generation': {'judgement': 'high/unclear'},
#   'allocation_concealment': {'judgement': 'high/unclear'},
#   'blinding_participants_personnel': {'judgement': 'high/unclear'}}]

# %%
abs_train.keys()
# Out:
# dict_keys(['ReviewID', 'SummaryBackground', 'SummaryConclusions', 'PMID', 'Title', 'Abstract'])

# %%
def make_abs_summ_data(abs_data):
    abs_rr_data = {}

    for abs_id, rid in abs_data['ReviewID'].items():
        summary_back = abs_data['SummaryBackground'][abs_id]
        summary_conc = abs_data['SummaryConclusions'][abs_id]
        pmid = abs_data['PMID'][abs_id]
        title = abs_data['Title'][abs_id]
        abstract = abs_data['Abstract'][abs_id]
        abs_rr_data[rid] = {'SummaryBackground': summary_back, 'SummaryConclusions': summary_conc, 
                             'PMID': pmid, 
                            'Title': title, 
                             'Abstract': abstract}
    #### sanity check #####  
    for k , v in abs_rr_train.items():
        if len(list(v.keys())) < 5:
            print(v.keys())
        
    return abs_rr_data

# %%
def make_struct_data(rr_data):
    struct_rr_data = {}
    for rid, pmid_values in rr_data.items():
        dict_values = {'sample_size': [], 'outcomes':[], 'punchline_text': []}
        for pmid in pmid_values:
            for k in dict_values.keys():
                dict_val = dict_values[k] + pmid[k] if type(pmid[k]) is list else [pmid[k]]
                dict_values[k] = list(set(dict_val))
        struct_rr_data[rid] = dict_values
        
    #### sanity check #####
    for k , v in struct_rr_train.items():
        if len(list(v.keys())) < 3:
            print(v.keys())
            
    return struct_rr_data

# %%
def make_tabular_data(struct_rr, abs_rr):
    all_data_src = []
    all_data_tgt = []
    for rid, rvalue in struct_rr.items():
        if rid in abs_rr:
            tgt_summary = abs_rr[rid]['SummaryConclusions']
        
            src_sents = [','.join(src_val) for k , src_val in rvalue.items()]
            all_data_src.append('|'.join(src_sents))
            all_data_tgt.append(tgt_summary)
    return all_data_src, all_data_tgt

# %%
def write_data(src_data, tgt_data, src_file, tgt_file):
    
    
    with open(src_file, 'w') as fp1:
        fp1.write('\n'.join(src_data))
    
        
    with open(tgt_file, 'w') as fp2:
        fp2.write('\n'.join(tgt_data))

# %%
rr_train = read_rr_file('/Users/sanjana/destruct/destruct/data/roboreviewer/RR-train.json')
abs_train = read_rr_file('/Users/sanjana/destruct/destruct/data/roboreviewer/abstracts-summarization-train.json')

# %%
abs_train = make_abs_summ_data(abs_train)
rr_train = make_struct_data(rr_train)

# %%
train_data_src, train_data_tgt = make_tabular_data(rr_train, abs_train)
write_data(train_data_src, train_data_tgt, 'src_rr_train.txt', 'tgt_rr_train.txt')

# %%
rr_test = read_rr_file('/Users/sanjana/destruct/destruct/data/roboreviewer/RR-test.json')
abs_test = read_rr_file('/Users/sanjana/destruct/destruct/data/roboreviewer/abstracts-summarization-test.json')
abs_test = make_abs_summ_data(abs_test)
rr_test = make_struct_data(rr_test)
test_data_src, test_data_tgt = make_tabular_data(rr_test, abs_test)
write_data(test_data_src, test_data_tgt, 'src_rr_test.txt', 'tgt_rr_test.txt')

# %%
rr_dev = read_rr_file('/Users/sanjana/destruct/destruct/data/roboreviewer/RR-dev.json')
abs_dev = read_rr_file('/Users/sanjana/destruct/destruct/data/roboreviewer/abstracts-summarization-dev.json')
abs_dev = make_abs_summ_data(abs_dev)
rr_dev = make_struct_data(rr_dev)
dev_data_src, dev_data_tgt = make_tabular_data(rr_dev, abs_dev)
write_data(dev_data_src, dev_data_tgt, 'src_rr_dev.txt', 'tgt_rr_dev.txt')
